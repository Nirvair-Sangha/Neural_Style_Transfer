# %%
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %%
def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

# %%
content_image = load_image('profile.jpg')
style_image = load_image('monet.jpg')
content_image3 = load_image('profile2.jpg')

# %%
content_image.shape
# Out:
# TensorShape([1, 1966, 2067, 3])

# %%
plt.imshow(np.squeeze(content_image))
plt.show()

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]

# %%
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
cv2.imwrite('cool_image.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
style_image2 = load_image('andy.png')

# %%
plt.imshow(np.squeeze(style_image2))
plt.show()

# %%
stylized_image2 = model(tf.constant(content_image), tf.constant(style_image2))[0]

# %%
plt.imshow(np.squeeze(stylized_image2))
plt.show()
cv2.imwrite('cool_ting.jpg', cv2.cvtColor(np.squeeze(stylized_image2)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
style_image3 = load_image('vangogh.jpg')

# %%
plt.imshow(np.squeeze(style_image3))
plt.show()

# %%
stylized_image3 = model(tf.constant(content_image3), tf.constant(style_image3))[0]

# %%
plt.imshow(np.squeeze(stylized_image3))
plt.show()

# %%
content_image2 = load_image('park.jpg')
style_image4 = load_image('starrynight.jfif')

# %%
stylized_image4 = model(tf.constant(content_image2), tf.constant(style_image4))[0]

# %%
plt.imshow(np.squeeze(stylized_image4))
plt.show()
